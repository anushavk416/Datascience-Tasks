# %% [markdown]
# <a href="https://colab.research.google.com/github/anushavk416/Datascience-Tasks/blob/main/loan_approval_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Loan approval prediction

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
df = pd.read_csv("loan_data.csv")
df.head()
# Out:
#    person_age person_gender  ... previous_loan_defaults_on_file  loan_status
# 0        22.0        female  ...                             No            1
# 1        21.0        female  ...                            Yes            0
# 2        25.0        female  ...                             No            1
# 3        23.0        female  ...                             No            1
# 4        24.0          male  ...                             No            1
#
# [5 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45000 entries, 0 to 44999
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   person_age                      45000 non-null  float64
#  1   person_gender                   45000 non-null  object
#  2   person_education                45000 non-null  object
#  3   person_income                   45000 non-null  float64
#  4   person_emp_exp                  45000 non-null  int64
#  5   person_home_ownership           45000 non-null  object
#  6   loan_amnt                       45000 non-null  float64
#  7   loan_intent                     45000 non-null  object
#  8   loan_int_rate                   45000 non-null  float64
#  9   loan_percent_income             45000 non-null  float64
#  10  cb_person_cred_hist_length      45000 non-null  float64
#  11  credit_score                    45000 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# person_age                        0
# person_gender                     0
# person_education                  0
# person_income                     0
# person_emp_exp                    0
# person_home_ownership             0
# loan_amnt                         0
# loan_intent                       0
# loan_int_rate                     0
# loan_percent_income               0
# cb_person_cred_hist_length        0
# credit_score                      0
# previous_loan_defaults_on_file    0
# loan_status                       0
# dtype: int64

# %%
df.describe()
# Out:
#          person_age  person_income  ...  credit_score   loan_status
# count  45000.000000   4.500000e+04  ...  45000.000000  45000.000000
# mean      27.764178   8.031905e+04  ...    632.608756      0.222222
# std        6.045108   8.042250e+04  ...     50.435865      0.415744
# min       20.000000   8.000000e+03  ...    390.000000      0.000000
# 25%       24.000000   4.720400e+04  ...    601.000000      0.000000
# 50%       26.000000   6.704800e+04  ...    640.000000      0.000000
# 75%       30.000000   9.578925e+04  ...    670.000000      0.000000
# max      144.000000   7.200766e+06  ...    850.000000      1.000000
#
# [8 rows x 9 columns]

# %%
#handling outliers in age column:
df = df[df['person_age']<=100]
df.describe()
# Out:
#          person_age  person_income  ...  credit_score   loan_status
# count  44993.000000   4.499300e+04  ...  44993.000000  44993.000000
# mean      27.748428   7.990845e+04  ...    632.585713      0.222257
# std        5.909737   6.332213e+04  ...     50.402411      0.415767
# min       20.000000   8.000000e+03  ...    390.000000      0.000000
# 25%       24.000000   4.719500e+04  ...    601.000000      0.000000
# 50%       26.000000   6.704600e+04  ...    640.000000      0.000000
# 75%       30.000000   9.577800e+04  ...    670.000000      0.000000
# max       94.000000   2.448661e+06  ...    784.000000      1.000000
#
# [8 rows x 9 columns]

# %%
df.drop_duplicates(inplace = True)
df.shape
# Out:
# (44993, 14)

# %%
df.head()
# Out:
#    person_age person_gender  ... previous_loan_defaults_on_file  loan_status
# 0        22.0        female  ...                             No            1
# 1        21.0        female  ...                            Yes            0
# 2        25.0        female  ...                             No            1
# 3        23.0        female  ...                             No            1
# 4        24.0          male  ...                             No            1
#
# [5 rows x 14 columns]

# %%
df['loan_status'].unique()
# Out:
# array([1, 0])

# %%
sns.histplot(df["loan_status"])
# Out:
# <Axes: xlabel='loan_status', ylabel='Count'>

# %%
sns.countplot(x = "person_gender", data = df, hue = "loan_status") #works well for object data
# Out:
# <Axes: xlabel='person_gender', ylabel='count'>

# %%
# which age grp who is getting more loans
sns.histplot(x = "person_age", data = df[df['loan_status']==1], kde = True, hue = "loan_status")
# Out:
# <Axes: xlabel='person_age', ylabel='Count'>

# %%
# who are getting based on education
sns.countplot(x = "person_education", data = df, hue = "loan_status")
# Out:
# <Axes: xlabel='person_education', ylabel='count'>

# %%
# with which avg income they're getting more loans
df.groupby("loan_status")['person_income'].mean()
# Out:
# loan_status
# 0    85630.263567
# 1    59886.096900
# Name: person_income, dtype: float64

# %%
df.head()
# Out:
#    person_age person_gender  ... previous_loan_defaults_on_file  loan_status
# 0        22.0        female  ...                             No            1
# 1        21.0        female  ...                            Yes            0
# 2        25.0        female  ...                             No            1
# 3        23.0        female  ...                             No            1
# 4        24.0          male  ...                             No            1
#
# [5 rows x 14 columns]

# %%
#person experience and loan
sns.scatterplot(x = "person_emp_exp", y = "loan_amnt", data = df)
# Out:
# <Axes: xlabel='person_emp_exp', ylabel='loan_amnt'>

# %% [markdown]
# ## label encoding

# %%
def encoding(df, col):
  LE = LabelEncoder()
  df[col] = LE.fit_transform(df[col])
  return df

df = encoding(df, "person_home_ownership")
df = encoding(df, "loan_intent")
df = encoding(df, "person_gender")
df = encoding(df, "person_education")
df = encoding(df, "previous_loan_defaults_on_file")

# %% [markdown]
# ##Model training

# %%
# dividing dataset
X = df.drop("loan_status", axis = 1)
y = df['loan_status']

# %%
Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, test_size = 0.3, random_state = 42)

# %%
#scaling
scaler = StandardScaler()
Xtrain = scaler.fit_transform(Xtrain)
Xtest = scaler.transform(Xtest)

# %%
model = SVC()
model.fit(Xtrain, ytrain)
# Out:
# SVC()

# %%
ypred = model.predict(Xtest)
ypred
# Out:
# array([1, 0, 0, ..., 1, 0, 1])

# %%
confusion_matrix(ytest, ypred)
# Out:
# array([[10044,   446],
#        [  792,  2216]])

# %%
print(classification_report(ytest, ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.96      0.94     10490
#            1       0.83      0.74      0.78      3008
#
#     accuracy                           0.91     13498
#    macro avg       0.88      0.85      0.86     13498
# weighted avg       0.91      0.91      0.91     13498

# %%
print("training eff:", model.score(Xtrain, ytrain))
print("testing eff:", model.score(Xtest, ytest))
# Out:
# training eff: 0.9132560723924432
# testing eff: 0.9082827085494147

# %%
newdata = df.iloc[:1, :-1]
newdata = scaler.transform(newdata)
pred = model.predict(newdata)

if pred==1:
  print("loan approved.")
else:
  print("loan not approved.")
# Out:
# loan approved.
